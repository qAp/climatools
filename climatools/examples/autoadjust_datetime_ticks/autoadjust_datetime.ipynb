# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import xarray as xr

import matplotlib 
import matplotlib.pyplot as plt

import climatools.viz as climaviz

# %%
n_datetimes = 33 * 24 * 60

datetimes = pd.date_range('2000-05-23 00:10:00', 
                          freq='Min', periods=n_datetimes)

data = np.sin(2 * np.pi / 24 * 
              np.array([datetime.hour for datetime in datetimes]))

da = xr.DataArray(data, dims=['time'], coords=[datetimes])

# %%
timeslice = slice('2000-05-30 00:02:00', '2000-05-31 14:03.10')

# %%
da.sel(time=timeslice).plot()

# %%
da_tmp = da.sel(time=timeslice)
x = [pd.Timestamp(dtns).to_datetime() 
     for dtns in da_tmp.coords['time'].values]
y = da_tmp.values

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 4))
ax.plot(x, y)
duration = pd.Timedelta(x[-1] - x[0])
climaviz.set_xaxis_datetime_ticklocs_ticklabels(ax.xaxis, 
                                                duration=duration)

# %%
timeslice = slice('2000-05-30 00:02:00', '2000-06-01 14:03.10')

# %%
da.sel(time=timeslice).plot()

# %%
da_tmp = da.sel(time=timeslice)
x = [pd.Timestamp(dtns).to_datetime() 
     for dtns in da_tmp.coords['time'].values]
y = da_tmp.values

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 4))
ax.plot(x, y)
duration = pd.Timedelta(x[-1] - x[0])
climaviz.set_xaxis_datetime_ticklocs_ticklabels(ax.xaxis, 
                                                duration=duration)

# %%
timeslice = slice('2000-05-30 00:02:00', '2000-06-10 14:03.10')

# %%
da.sel(time=timeslice).plot()

# %%
da_tmp = da.sel(time=timeslice)
x = [pd.Timestamp(dtns).to_datetime() 
     for dtns in da_tmp.coords['time'].values]
y = da_tmp.values

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 4))
ax.plot(x, y)
duration = pd.Timedelta(x[-1] - x[0])
climaviz.set_xaxis_datetime_ticklocs_ticklabels(ax.xaxis, 
                                                duration=duration)
